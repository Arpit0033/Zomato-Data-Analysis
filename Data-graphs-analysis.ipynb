# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Arpit kumar\Arpit python\zomato.csv", encoding='latin1')

print(df.head())
print(df.shape)
plt.savefig("distribution_of_ratings.png")
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
country_counts = df['Country Code'].value_counts().head(10)
sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")
plt.title("Top 10 Countries by Number of Restaurants")
plt.xlabel("Country Code")
plt.ylabel("Number of Restaurants")
plt.savefig("distribution_of_ratings.png")  
plt.show()
# Out:
# C:\Users\Arpit kumar\AppData\Local\Temp\ipykernel_5912\3556616375.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")

# %%
plt.figure(figsize=(12,6))
city_ratings = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=city_ratings.index, y=city_ratings.values, palette="rocket")
plt.title("Top 10 Cities by Average Rating")
plt.xticks(rotation=45)
plt.ylabel("Average Rating")
plt.savefig("distribution_of_ratings.png")  
plt.show()
# Out:
# C:\Users\Arpit kumar\AppData\Local\Temp\ipykernel_5912\309797100.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_ratings.index, y=city_ratings.values, palette="rocket")

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Aggregate rating'], bins=10, kde=True, color='orange')
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Aggregate Rating")
plt.ylabel("Count")
plt.savefig("distribution_of_ratings.png")  
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='Has Online delivery', y='Aggregate rating', data=df)
plt.title("Online Delivery Availability vs Rating")
plt.savefig("distribution_of_ratings.png")  
plt.show()

# %%
plt.figure(figsize=(12,6))
df['Cuisines'].value_counts().head(10).plot(kind='bar', color='teal')
plt.title("Top 10 Most Popular Cuisines")
plt.ylabel("Number of Restaurants")
plt.savefig("distribution_of_ratings.png")  
plt.savefig("distribution_of_ratings.png")  
plt.show()

# %%
top_countries = df['Country Code'].value_counts().head(10)
plt.figure(figsize=(8,5))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title("Top 10 Countries with Most Restaurants")
plt.xlabel("Country Code")
plt.ylabel("Number of Restaurants")
plt.savefig("top_countries.png")  # ✅ ye line graph save karegi
plt.show()
